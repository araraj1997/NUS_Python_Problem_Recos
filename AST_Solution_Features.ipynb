# %% [markdown]
# We need to create a function which can be passed some python 3 code and returns a dictionary containing all of the functions, expressions, and modules used by the python code.
#
# Documentation: https://greentreesnakes.readthedocs.io/en/latest/nodes.html
#
# ###List all statements used
# `    ['for', 'while', 'if','else','elif']`
# ###List all functions used
# `    ['.reverse', 'reverse', '.sort', 'sorted', 'len']`
#
# ###List all modules imported
# `    ['Math']`
#
# ###List all expressions used
# `    ['+','-','*','=','==']`

# %%
# Example parser
import ast
def code_features(code):
    result = {
        "statements":{},
        "functions":{},
        "imports":{},
        "expressions":{}
    }
    return result

# %%
# Collect all statements
def getAllStat(tree):
  stat = {}
  for node in ast.walk(tree):
    if isinstance(node, ast.While):
      stat["While"] = True
    elif isinstance(node, ast.For):
      stat["For"] = True
    elif isinstance(node, ast.Return):
      stat["Return"] = True
    elif isinstance(node, ast.If):
      stat["If"] = True
    #else:
    #  print(node)

  return stat

# %%
# Alternate approach for functions.

'''
Get all function calls from a python file
The MIT License (MIT)
Copyright (c) 2016 Suhas S G <jargnar@gmail.com>
'''
import ast
from collections import deque


class FuncCallVisitor(ast.NodeVisitor):
    def __init__(self):
        self._name = deque()

    @property
    def name(self):
        #print(self._name)
        return '.'.join(self._name)


    @name.deleter
    def name(self):
        self._name.clear()

    # Updating to only show obj for ids
    def visit_Name(self, node):
        self._name.appendleft(node.id)


    def visit_Attribute(self, node):
        try:
            self._name.appendleft(node.attr)
            # hacking for demonstration list of functions
            #self._name.appendleft(node.value.id)
            self._name.appendleft("")

            #print(node.value.id)
        except AttributeError:
            self.generic_visit(node)


def get_func_calls(tree):
    func_calls = []
    for node in ast.walk(tree):
        if isinstance(node, ast.Call):
            callvisitor = FuncCallVisitor()
            callvisitor.visit(node.func)
            func_calls.append(callvisitor.name)
    result = {}
    for item in func_calls:
      result[item] = True
    #return sorted(list(set(func_calls)))
    return result

# %%
# Collect all imports
def getAllImports(a):
	"""Gather all imported module names"""
	if not isinstance(a, ast.AST):
		return set()
	imports = set()
	for child in ast.walk(a):
		if type(child) == ast.Import:
			for alias in child.names:
					imports.add(alias.asname if alias.asname != None else alias.name)
		elif type(child) == ast.ImportFrom:
				for alias in child.names: # these are all functions
						imports.add(alias.asname if alias.asname != None else alias.name)


	result = {}
	for item in imports:
	  result[item] = True
	return result

	#return sorted(list(imports))

# %%
# Collect all expressions
def getAllExpr(tree):
  expr = []
  for node in ast.walk(tree):
    if isinstance(node, ast.Add):
      expr.append("+")
    if isinstance(node, ast.Eq):
      expr.append("==")
    if isinstance(node, ast.Sub):
      expr.append("-")
    if isinstance(node, ast.Mult):
      expr.append("*")
    if isinstance(node, ast.Div):
      expr.append("/")
    if isinstance(node, ast.Lt):
      expr.append("<")
    if isinstance(node, ast.Gt):
      expr.append(">")

  result = {}
  for item in expr:
    result[item] = True
  return result

  #return sorted(list(set(expr)))

# %%
def code_features(src):
  tree = ast.parse(src)
  result = {
        "statements":{},
        "functions":{},
        "imports":{},
        "expressions":{}
    }
  result["imports"] = getAllImports(tree)
  result["expressions"] =getAllExpr(tree)
  result["functions"] = get_func_calls(tree)
  result["statements"] = getAllStat(tree)
  return result

# %%
# Here are some code examples to practice parsing with.
import ast

src1 = '''
def f1(l):
    l.reverse()
    if(true):
      return l
    return l
'''
src2 = '''
def f1(l):
    l.reverse()
    reverse(l)
    l.sort()
    sorted(l)
    len(l)
    for x in l:
        pass
    return(l)
'''
src3 = '''
import Math
def f1(l):
    x = 0
    while x < 5:
        x += 1
    return(l)

'''

example_solutions = {
    "a": src1,
    "b": src2,
    "c": src3
}

# %%
for key, src in example_solutions.items():
  results = code_features(src)
  print(key,results)
# Out:
# a {'statements': {'If': True, 'Return': True}, 'functions': {'.reverse': True}, 'imports': {}, 'expressions': {}}
# b {'statements': {'For': True, 'Return': True}, 'functions': {'.reverse': True, 'reverse': True, '.sort': True, 'sorted': True, 'len': True}, 'imports': {}, 'expressions': {}}
# c {'statements': {'While': True, 'Return': True}, 'functions': {}, 'imports': {'Math': True}, 'expressions': {'<': True, '+': True}}

# %%
# We have provided some example solution data hosted on Amazon S3
"""
{ problemKey1: {
     solutionKey1: {},
     solutionKey2: {}
  },
  problemKey2: {
     userKey1: {},
     userKey2: {}
  }
}

"""

url = "https://s3-ap-southeast-1.amazonaws.com/alset-public/example_solutions.json"
import urllib.request
import json
req = urllib.request.Request(url)

##parsing response
r = urllib.request.urlopen(req).read()
student_solutions = json.loads(r.decode('utf-8'))

for problemKey in student_solutions.keys():
  #print(problemKey)
  for userKey in student_solutions[problemKey].keys():
    #print("   ",userKey)
    #print(student_solutions[problemKey][userKey])
    pass

# %%
#Try listing funcitons from the student_solutions
for problemKey in student_solutions.keys():
  print("problem",problemKey)
  for userKey in student_solutions[problemKey].keys():
    #print(student_solutions[problemKey][userKey])
    src = student_solutions[problemKey][userKey]
    #function_calls = get_func_calls(ast.parse(src))
    print("---------------------")
    print(src)
    for key, value in code_features(src).items():
      print(key, value)
# Out:
# problem -LDkAuy-IFXOJoBILgL6
# ---------------------
# # def multiply
# def multiply(x, y):
#     return x*y
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(x,y):
#     return x*y
#
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(x,y):
#     return x*y
#
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(x,y):
#     return x*y
#
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# # def multiply
# def multiply(x,y):
#   return x*y
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(a,b):
#     return a*b
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(x,y): return x*y
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(a, b):
#     return a * b
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(x, y):
#     return x*y
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(x,y):
#     return x*y
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(n1,n2):
#     return n1*n2
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(num1, num2):
#     return num1 * num2
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(a, b): return a * b
#
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(a, b):
#     return a*b
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(x, y):
#     return x * y
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(a,b):
#     return a*b
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(a,b):
#     return a*b
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(a, b):
#     return (a*b)
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(x,y):
#     return x*y
#
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(x,y):
#     return x*y
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(n1,n2):
#     return n1*n2
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(a,b):
#     return a * b
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# # def multiply
# def multiply(num1, num2):
#     return num1 * num2
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# ---------------------
# def multiply(a, b):
#     return a * b
#
#
# statements {'Return': True}
# functions {}
# imports {}
# expressions {'*': True}
# problem -LDkAxmbeJ9r3DcfU0ZW
# ---------------------
# # def sign
# def sign(x):
#     if x > 0:
#         return 1
#     elif x == 0:
#         return 0
#     else:
#         return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '==': True}
# ---------------------
# # def sign
# def sign(x):
#     if x>0:return 1
#     if x==0:return 0
#     else:return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '==': True}
# ---------------------
# def sign(x):
#     if x > 0:
#         return 1
#     elif x < 0:
#         return -1
#     else:
#         return 0
#
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '<': True}
# ---------------------
# def sign(number):
#     if number > 0:
#         return 1
#     elif number == 0:
#         return 0
#     else:
#         return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '==': True}
# ---------------------
# # def sign
# def sign(x):
#     if x > 0:
#         return 1
#     elif x == 0:
#         return 0
#     else:
#         return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '==': True}
# ---------------------
# # def sign
# def sign(num):
#     if num == 0:
#         return 0
#     elif num > 0:
#         return 1
#     else:
#         return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'==': True, '>': True}
# ---------------------
# def sign(x):
#     if x < 0: return -1
#     if not x: return 0
#     return 1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'<': True}
# ---------------------
# def sign(a):
#     if a > 0:
#         return 1
#     elif a == 0:
#         return 0
#     else:
#         return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '==': True}
# ---------------------
# def sign(x):
#     if x > 0:
#         return 1
#     if x == 0:
#         return 0
#     return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '==': True}
# ---------------------
# def sign(n):
#     if n<0:
#         return -1
#     elif n==0:
#         return 0
#     else:
#         return 1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'<': True, '==': True}
# ---------------------
# def sign(num):
#     if num > 0: return 1
#     elif num < 0: return -1
#     else: return 0
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '<': True}
# ---------------------
# def sign(x):
#     if x > 0:
#         return 1
#     elif x == 0:
#         return 0
#     else:
#         return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '==': True}
# ---------------------
# # def sign
# def sign(x):
#     if ((x*-1) > 0): return -1
#     if ((x*-1) < 0): return 1
#     return 0
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '<': True, '*': True}
# ---------------------
# def sign(x):
#     if x>0: return 1
#     if x==0: return 0
#     return -1
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '==': True}
# ---------------------
# # def sign
# def sign(number):
#     if number < 0:
#         return -1
#     elif number > 0:
#         return 1
#     else:
#         return 0
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'<': True, '>': True}
# ---------------------
# # def sign
# def sign(a):
#     if a > 0:
#         return 1
#     if a < 0:
#         return -1
#     return 0
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '<': True}
# ---------------------
# # def sign
# def sign(myNumber):
#     if myNumber > 0:
#         return 1
#     elif myNumber < 0:
#         return -1
#     else:
#         return 0
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '<': True}
# ---------------------
# def sign(n):
#     if n > 0:
#         return 1
#     elif n < 0:
#         return -1
#     else:
#         return 0
#
#
# statements {'If': True, 'Return': True}
# functions {}
# imports {}
# expressions {'>': True, '<': True}
# problem -LDkB1-McVTufbnKUw-8
# ---------------------
# #def count_evens
# def count_evens(l):
#     total = 0
#     for i in l:
#         if i % 2 == 0:
#             total += 1
#     return total
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# #def count_evens
# def count_evens(x):
#     a=0
#     for i in x:
#         if i%2==0:
#             a+=1
#     return a
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def count_evens(lst):
#     product = 0
#     for i in lst:
#         if i%2 == 0:
#             product += 1
#         else:
#             continue
#     return product
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def count_evens(num_array):
#     count = 0
#     for item in num_array:
#         if item % 2 == 0:
#             count += 1
#     return count
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# #def count_evens
# def count_evens(l):
#     ct = 0
#     for e in l:
#         if e % 2 == 0:
#             ct += 1
#     return ct
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# #def count_evens
# def count_evens(lst):
#     counter = 0
#     if len(lst) > 0:
#         for i in lst:
#             if i % 2 == 0:
#                 counter += 1
#     return counter
#
# statements {'If': True, 'Return': True, 'For': True}
# functions {'len': True}
# imports {}
# expressions {'>': True, '==': True, '+': True}
# ---------------------
# def count_evens(ls):
#     return len([x for x in ls if not x % 2])
#
#
# statements {'Return': True}
# functions {'len': True}
# imports {}
# expressions {}
# ---------------------
# def count_evens(i):
#     return len([x for x in i if x % 2 == 0])
#
#
# statements {'Return': True}
# functions {'len': True}
# imports {}
# expressions {'==': True}
# ---------------------
# def count_evens(list):
#     counter=0
#     for i in list:
#         if i%2==0:
#             counter+=1
#     return counter
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def count_evens(lst):
#     return sum([1 for x in lst if x % 2 == 0])
#
#
# statements {'Return': True}
# functions {'sum': True}
# imports {}
# expressions {'==': True}
# ---------------------
# #def count_evens
# def count_evens(x):
#     count = 0
#     for i in x:
#         if i%2 == 0:
#             count += 1
#     return count
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def count_evens(lst):
#     cnt=0
#     for i in lst:
#         if i%2==0:
#             cnt+=1
#     return cnt
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# #def count_evens
# def count_evens(lst):
#     if len(lst) < 2:
#         return 0
#     count = 0
#     for number in lst:
#         if number % 2 == 0:
#             count += 1
#     return count
#
#
# statements {'If': True, 'For': True, 'Return': True}
# functions {'len': True}
# imports {}
# expressions {'<': True, '==': True, '+': True}
# ---------------------
# #def count_evens
# def count_evens(input):
#     return len(list(filter(lambda x: x % 2 == 0, input)))
#
#
# statements {'Return': True}
# functions {'len': True, 'list': True, 'filter': True}
# imports {}
# expressions {'==': True}
# ---------------------
# #def count_evens
# def count_evens(numList):
#     numEvens = 0
#     for num in numList:
#         if num % 2 == 0:
#             numEvens += 1
#     return numEvens
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def count_evens(l):
#     return sum(1 if x % 2 == 0 else 0 for x in l)
#
#
# statements {'Return': True}
# functions {'sum': True}
# imports {}
# expressions {'==': True}
# problem -LDkB3z2Pp9wRf-zCxBk
# ---------------------
# # def sum_list(l):
# def sum_list(l):
#     return sum(l)
#
#
# statements {'Return': True}
# functions {'sum': True}
# imports {}
# expressions {}
# ---------------------
# # def sum_list(l):
# def sum_list(l):
#     a=0
#     for i in l:
#         a+=i
#     return a
#
#
# statements {'For': True, 'Return': True}
# functions {}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_list(mylist):
#     if len(mylist) == 0:
#         return 0
#     else:
#         product = 0
#         for i in mylist:
#             product += i
#         return product
#
#
# statements {'If': True, 'Return': True, 'For': True}
# functions {'len': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def sum_list(input_list):
#     current_sum = 0
#     for item in input_list:
#         current_sum += item
#     return current_sum
#
#
# statements {'For': True, 'Return': True}
# functions {}
# imports {}
# expressions {'+': True}
# ---------------------
# # def sum_list(l):
# def sum_list(l):
#     s = 0
#     for e in l:
#         s += e
#     return s
#
#
# statements {'For': True, 'Return': True}
# functions {}
# imports {}
# expressions {'+': True}
# ---------------------
# # def sum_list(l):
# def sum_list(l):
#     total = 0
#     for i in l:
#         total += i
#     return total
#
# statements {'For': True, 'Return': True}
# functions {}
# imports {}
# expressions {'+': True}
# ---------------------
# sum_list = sum
#
#
# statements {}
# functions {}
# imports {}
# expressions {}
# ---------------------
# def sum_list(l):
#     return sum(l)
#
#
# statements {'Return': True}
# functions {'sum': True}
# imports {}
# expressions {}
# ---------------------
# def sum_list(l):
#     counter=0
#     for i in l:
#         counter+=int(i)
#     return counter
#
#
# statements {'For': True, 'Return': True}
# functions {'int': True}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_list(l):
#     return sum(l)
#
#
# statements {'Return': True}
# functions {'sum': True}
# imports {}
# expressions {}
# ---------------------
# # def sum_list(l):
# def sum_list(l):
#     count = 0
#     for i in l:
#         count += i
#     return count
#
#
# statements {'For': True, 'Return': True}
# functions {}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_list(lst):
#     return sum(lst)
#
#
# statements {'Return': True}
# functions {'sum': True}
# imports {}
# expressions {}
# ---------------------
# # def sum_list(l):
# def sum_list(lst):
#     total = 0
#     for number in lst:
#         total += number
#     return total
#
#
# statements {'For': True, 'Return': True}
# functions {}
# imports {}
# expressions {'+': True}
# ---------------------
# # def sum_list(l):
# def sum_list(input):
#     return sum(input)
#
#
# statements {'Return': True}
# functions {'sum': True}
# imports {}
# expressions {}
# ---------------------
# # def sum_list(l):
# def sum_list(l):
#     sum = 0
#     for num in l:
#         sum += num
#     return sum
#
#
# statements {'For': True, 'Return': True}
# functions {}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_list(l):
#     return sum(l)
#
#
# statements {'Return': True}
# functions {'sum': True}
# imports {}
# expressions {}
# problem -LDkB7FprNZsNyK67zFC
# ---------------------
# # def sum_numbers
# def sum_numbers(l):
#     total = 0
#     for i in l:
#         if type(i) is int or type(i) is float:
#             total += i
#     return total
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'+': True}
# ---------------------
# # def sum_numbers
# def sum_numbers(x):
#     a=0
#     for i in x:
#         if type(i)==int or type(i)==float:
#             a+=i
#         else:
#             continue
#     return a
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'+': True, '==': True}
# ---------------------
# def sum_numbers(mylist):
#     if len(mylist) == 0:
#         return 0
#     else:
#         product = 0
#         for i in mylist:
#             if type(i) == int or type(i) == float:
#                 product += i
#             else:
#                 continue
#         return product
#
#
#
# statements {'If': True, 'Return': True, 'For': True}
# functions {'len': True, 'type': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def sum_numbers(list):
#     new_list = [
#         item for item in list
#         if not isinstance(item, str)
#         ]
#     sum = 0
#     for item in new_list:
#         sum += item
#     return sum
#
#
# statements {'For': True, 'Return': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True}
# ---------------------
# # def sum_numbers
# def sum_numbers(l):
#     s = 0
#     for e in l:
#         if isinstance(e, str):
#
#             e = 0
#
#         s += e
#     return s
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True}
# ---------------------
# # def sum_numbers
# def sum_numbers(lst):
#     total = 0
#     for i in lst:
#         if isinstance(i,str):
#             continue
#         total += i
#     return total
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_numbers(ls):
#     return sum(x for x in ls if not isinstance(x, str))
#
#
# statements {'Return': True}
# functions {'sum': True, 'isinstance': True}
# imports {}
# expressions {}
# ---------------------
# def sum_numbers(i):
#     total = 0
#     for x in i:
#         if type(x) is not int and type(x) is not float:
#             continue
#         total += x
#     return total
#
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_numbers(l):
#     counter=0
#     for i in l:
#         if type(i)==str:
#             pass
#         else:
#             counter+=i
#     return counter
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def sum_numbers(lst):
#     def guess(num):
#         if type(num) is str:
#             return 0
#         else: return num
#     return sum(map(guess, lst))
#
#
# statements {'Return': True, 'If': True}
# functions {'sum': True, 'map': True, 'type': True}
# imports {}
# expressions {}
# ---------------------
# # def sum_numbers
# def sum_numbers(x):
#     count = 0
#     for i in x:
#         if isinstance(i, int) or isinstance(i, float):
#             count += i
#     return count
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_numbers(lst):
# 	cnt=0
# 	for i in lst:
# 		if type(i)==int or type(i)==float:
# 			cnt+=i
# 	return cnt
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'+': True, '==': True}
# ---------------------
# # def sum_numbers
# def sum_numbers(lst):
#     total = 0
#     for number in lst:
#         if type(number) == str:
#             continue
#         else:
#             total += number
#     return total
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# # def sum_numbers
# def sum_numbers(input):
#     return sum(list(filter(lambda x: isinstance(x, int) or isinstance(x, float), input)))
#
#
# statements {'Return': True}
# functions {'sum': True, 'list': True, 'filter': True, 'isinstance': True}
# imports {}
# expressions {}
# ---------------------
# # def sum_numbers
# def sum_numbers(myList):
#     sum = 0
#     for val in myList:
#         if not isinstance(val, str):
#             sum += val
#     return sum
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_numbers(l):
#     return sum(x for x in l if not isinstance(x, str))
#
#
# statements {'Return': True}
# functions {'sum': True, 'isinstance': True}
# imports {}
# expressions {}
# problem -LDkBAqpHP6trY1K4Bj5
# ---------------------
# # def sum_odd_numbers
# def sum_odd_numbers(l):
#     total = 0
#     for i in l:
#         try:
#             if i % 2 == 1:
#                 total += i
#         except:
#             pass
#     return total
#
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# # def sum_odd_numbers
# def sum_odd_numbers(x):
#     a=0
#     for i in x:
#         if type(i)==int:
#             if i%2==1:
#
#                 a+=i
#     return a
#
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def sum_odd_numbers(mylist):
#     if len(mylist) == 0:
#         return 0
#     else:
#         product = 0
#         for i in mylist:
#             if type(i) == int and i%2 == 1:
#                 product += i
#             else:
#                 continue
#         return product
#
#
#
# statements {'If': True, 'Return': True, 'For': True}
# functions {'len': True, 'type': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def sum_odd_numbers(list):
#     odd_non_str_list = [
#         item for item in list
#         if not isinstance(item, str)
#         and item % 2 == 1
#     ]
#     sum = 0
#     for item in odd_non_str_list:
#         sum += item
#     return sum
#
#
# statements {'For': True, 'Return': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True, '==': True}
# ---------------------
# # def sum_odd_numbers
# def sum_odd_numbers(l):
#     s=0
#     for e in l:
#         if isinstance(e, str):
#             continue
#         if e%2 == 1:
#             s += e
#     return s
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'isinstance': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# # def sum_odd_numbers
# def sum_odd_numbers(lst):
#     total = 0
#     for i in lst:
#         if isinstance(i,str):
#             continue
#         else:
#             if i % 2 == 0:
#                 continue
#         total+=i
#     return total
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True, '==': True}
# ---------------------
# def sum_odd_numbers(ls):
#     return sum(x for x in ls if not isinstance(x, str) and x % 2)
#
#
# statements {'Return': True}
# functions {'sum': True, 'isinstance': True}
# imports {}
# expressions {}
# ---------------------
# def sum_odd_numbers(l):
#     counter=0
#     for i in l:
#         if type(i)==str:
#             pass
#         else:
#             if i%2==0:
#                 pass
#             else:
#                 counter+=i
#     return counter
#
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# def sum_odd_numbers(lst):
#     return sum([x for x in lst if type(x) is int and  x % 2 == 1])
#
#
# statements {'Return': True}
# functions {'sum': True, 'type': True}
# imports {}
# expressions {'==': True}
# ---------------------
# # def sum_odd_numbers
# def sum_odd_numbers(x):
#     count = 0
#     for i in x:
#         if isinstance(i, int) and (i%2 != 0):
#             count += i
#     return count
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True}
# ---------------------
# def sum_odd_numbers(lst):
# 	cnt=0
# 	for i in lst:
# 		if (type(i)==int or type(i)==float) and int(i)%2==1:
# 			cnt+=i
# 	return cnt
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True, 'int': True}
# imports {}
# expressions {'+': True, '==': True}
# ---------------------
# # def sum_odd_numbers
# def sum_odd_numbers(lst):
#     total = 0
#     for number in lst:
#         if type(number) == str:
#             continue
#         elif number % 2 != 0:
#             total += number
#     return total
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'type': True}
# imports {}
# expressions {'==': True, '+': True}
# ---------------------
# # def sum_odd_numbers
# def sum_odd_numbers(input):
#     return sum(list(filter(lambda x: isinstance(x, float) or isinstance(x, int) and x % 2 != 0, input)))
#
#
# statements {'Return': True}
# functions {'sum': True, 'list': True, 'filter': True, 'isinstance': True}
# imports {}
# expressions {}
# ---------------------
# # def sum_odd_numbers
# def sum_odd_numbers(myList):
#     sum = 0
#     for num in myList:
#         if not isinstance(num, str) and num % 2 == 1:
#             sum += num
#     return sum
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'isinstance': True}
# imports {}
# expressions {'+': True, '==': True}
# ---------------------
# def sum_odd_numbers(l):
#     return sum(x if not isinstance(x, str) and x % 2 == 1 else 0 for x in l)
#
#
# statements {'Return': True}
# functions {'sum': True, 'isinstance': True}
# imports {}
# expressions {'==': True}
# problem -LDkBE8kMmBdo9gKt02Z
# ---------------------
# #def replace(template, target, new_value)
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
#
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# #def replace(template, target, new_value)
#
# def replace(l, x, a):
#     return l.replace(x, a)
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# #def replace(template, target, new_value)
# def replace(x,y,z):
#     if y in x:
#         j = x.replace(y,z)
#     return j
#
#
# statements {'If': True, 'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# def replace(template, target, new_value):
# 	while template.find(target)!=-1:
# 		ind = template.find(target)
# 		template=template[0:ind]+new_value+template[ind+len(target):]
# 	return template
#
#
# statements {'While': True, 'Return': True}
# functions {'.find': True, 'len': True}
# imports {}
# expressions {'+': True}
# ---------------------
# #def replace(template, target, new_value)
# def replace(template, target, new_value):
#     for count in range(len(template)-(len(target)-1)):
#         if target == template[count:count+len(target)]:
#             template = template[:count] + new_value + template[count+len(target):]
#     return template
#
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'range': True, 'len': True}
# imports {}
# expressions {'-': True, '==': True, '+': True}
# ---------------------
# #def replace(template, target, new_value)
#
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# #def replace(template, target, new_value)
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# ---------------------
# def replace(template, target, new_value):
#     return template.replace(target, new_value)
#
#
#
# statements {'Return': True}
# functions {'.replace': True}
# imports {}
# expressions {}
# problem -LDkBHslDND-YNg-u9i1
# ---------------------
# #def swap
# def swap(d):
#     return dict(zip(d.values(), d.keys()))
#
#
# statements {'Return': True}
# functions {'dict': True, 'zip': True, '.values': True, '.keys': True}
# imports {}
# expressions {}
# ---------------------
# def swap(dic):
#     tup = ()
#     for i in dic:
#         tup = tup + ((dic[i],i),)
#     new_tup = dict(tup)
#     return(new_tup)
#
#
#
# statements {'For': True, 'Return': True}
# functions {'dict': True}
# imports {}
# expressions {'+': True}
# ---------------------
# def swap(input_dic):
#     new_dic = {}
#     for key, value in tuple(input_dic.items()):
#         new_dic[value] = key
#     return new_dic
#
#
# statements {'For': True, 'Return': True}
# functions {'tuple': True, '.items': True}
# imports {}
# expressions {}
# ---------------------
# #def swap
# def swap(d):
#     c = dict()
#     for k in d:
#         c[d[k]] = k
#     return c
#
#
# statements {'For': True, 'Return': True}
# functions {'dict': True}
# imports {}
# expressions {}
# ---------------------
# def swap(d):
#     return {v: k for k, v in d.items()}
#
#
# statements {'Return': True}
# functions {'.items': True}
# imports {}
# expressions {}
# ---------------------
# def swap(d):
#     a=eval(str(d.values())[12:-1])
#     b=eval(str(d.keys())[10:-1])
#     c=dict()
#     counter=0
#     while counter<len(a):
#         c[a[counter]]=b[counter]
#         counter+=1
#     return c
#
#
# statements {'While': True, 'Return': True}
# functions {'eval': True, 'dict': True, 'len': True, 'str': True, '.values': True, '.keys': True}
# imports {}
# expressions {'<': True, '+': True}
# ---------------------
# def swap(kvs):
#     return {v:k for k,v in kvs.items()}
#
#
# statements {'Return': True}
# functions {'.items': True}
# imports {}
# expressions {}
# ---------------------
# #def swap
# def swap(d):
#     d2 = {}
#     for key, value in d.items():
#         d2[value] = key
#     return d2
#
#
# statements {'For': True, 'Return': True}
# functions {'.items': True}
# imports {}
# expressions {}
# ---------------------
# def swap(a):
# 	return dict((v,k) for k,v in a.items())
#
#
# statements {'Return': True}
# functions {'dict': True, '.items': True}
# imports {}
# expressions {}
# ---------------------
# #def swap
# def swap(dic):
#     side_1 = list(dic.values())
#     side_2 = list(dic.keys())
#     new_dic = {}
#     for count in range(len(side_1)):
#         new_dic[side_1[count]] = side_2[count]
#     return new_dic
#
#
#
#
#
# statements {'For': True, 'Return': True}
# functions {'list': True, 'range': True, '.values': True, '.keys': True, 'len': True}
# imports {}
# expressions {}
# ---------------------
# #def swap
# def swap(input):
#     return dict(zip(input.values(), input.keys()))
#
#
# statements {'Return': True}
# functions {'dict': True, 'zip': True, '.values': True, '.keys': True}
# imports {}
# expressions {}
# ---------------------
# #def swap
# def swap(myDict):
#     newDict = {}
#     for key, value in myDict.items():
#         newDict[value] = key
#     return newDict
#
#
# statements {'For': True, 'Return': True}
# functions {'.items': True}
# imports {}
# expressions {}
# ---------------------
# def swap(d):
#     return dict(x[::-1] for x in d.items())
#
#
# statements {'Return': True}
# functions {'dict': True, '.items': True}
# imports {}
# expressions {}
# problem -LDkBNZ-WjGg-vAEHofN
# ---------------------
# # def histogram
# from collections import Counter
# def histogram(x):
#     return Counter(x)
#
#
# statements {'Return': True}
# functions {'Counter': True}
# imports {'Counter': True}
# expressions {}
# ---------------------
# def histogram(tup):
#     empty = ()
#     for i in tup:
#         if i in empty:
#             continue
#         else:
#             empty += (i,)
#     result = ()
#     count = 0
#     for j in empty:
#         for k in tup:
#             if j == k:
#                 count += 1
#             else:
#                 continue
#         result += ((j,count),)
#         count = 0
#     return dict(result)
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'dict': True}
# imports {}
# expressions {'+': True, '==': True}
# ---------------------
# def histogram(input_str):
#     histogram_dic = {}
#     alphabet_list = list(input_str)
#     for letter in alphabet_list:
#         histogram_dic[letter] = input_str.count(letter)
#         histogram_dic[' '] = input_str.count(' ')
#     return histogram_dic
#
#
# statements {'For': True, 'Return': True}
# functions {'list': True, '.count': True}
# imports {}
# expressions {}
# ---------------------
# # def histogram
# def histogram(s):
#     d = dict()
#     for c in s:
#         if not c in d:
#             d[c] = 1
#         else:
#             d[c] += 1
#     return d
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'dict': True}
# imports {}
# expressions {'+': True}
# ---------------------
# from collections import Counter as histogram
#
#
#
# statements {}
# functions {}
# imports {'histogram': True}
# expressions {}
# ---------------------
# from collections import Counter
# def histogram(s):
#     return Counter(s)
#
#
# statements {'Return': True}
# functions {'Counter': True}
# imports {'Counter': True}
# expressions {}
# ---------------------
# # def histogram
# def histogram(s):
#     d = {}
#     for i in s:
#         if i not in d.keys():
#             d[i] = 1
#         else:
#             d[i] += 1
#     return d
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'.keys': True}
# imports {}
# expressions {'+': True}
# ---------------------
# from collections import Counter
# def histogram(h):
# 	return dict(Counter(h))
#
#
# statements {'Return': True}
# functions {'dict': True, 'Counter': True}
# imports {'Counter': True}
# expressions {}
# ---------------------
# # def histogram
# def histogram(sentence):
#     dic = {}
#     lst = [] #list of letters
#     for letter in sentence:
#         if letter not in lst:
#             lst += letter
# ##    print(lst)
#     for var in lst:
#         count = 0
#         for l in sentence:
#             if l == var:
#                 count += 1
#         dic[var] = count
#     return dic
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'+': True, '==': True}
# ---------------------
# # def histogram
# def histogram(input):
#     from collections import defaultdict
#     occurences = defaultdict(int)
#     for x in input:
#         occurences[x] += 1
#     return occurences
#
#
# statements {'For': True, 'Return': True}
# functions {'defaultdict': True}
# imports {'defaultdict': True}
# expressions {'+': True}
# ---------------------
# # def histogram
# def histogram(myString):
#     myDict = {}
#     for char in myString:
#         if char in myDict:
#             myDict[char] += 1
#         else:
#             myDict[char] = 1
#     return myDict
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {}
# imports {}
# expressions {'+': True}
# ---------------------
# def histogram(s):
#     d = dict()
#     for c in s:
#         if c in d:
#             d[c] += 1
#         else:
#             d[c] = 1
#     return d
#
#
# statements {'For': True, 'Return': True, 'If': True}
# functions {'dict': True}
# imports {}
# expressions {'+': True}

# %%
# Unit testing for code_features() function.

import unittest

src1 = '''
def f1(l):
    import datetime
    l.reverse()
    if(true):
      return l
    return l
'''



src2 = '''
def count_evens(i):
    return len([x for x in i if x % 2 == 0])

'''

class TestCodeFeatures(unittest.TestCase):

    def setUp(self):
        pass

    def test_default(self, src=""):
        code_features(src)

    def test_statements(self, src=src1):
        result = code_features(src)
        self.assertEqual(code_features(src)["statements"], {'If':True,'Return':True})

    def test_functions(self, src=src1):
        self.assertEqual(code_features(src)["functions"], {'.reverse':True})

    def test_imports(self, src=src1):
        self.assertEqual(code_features(src)["imports"], {'datetime':True})

    def test_len(self, src=src2):
        result = code_features(src)
        self.assertEqual(result["functions"], {'len':True})

    def test_more_expressions(self, src=src2):
        result = code_features(src)
        self.assertEqual(result["expressions"], {'==':True})

    def test_more_statements(self, src=src2):
        result = code_features(src)
        self.assertEqual(result["statements"], {'Return':True})
        #Todo - This is what should be returned. Missing the list expression content.
        #self.assertEqual(result["statements"], {'Return':True,'For':True, 'In':True, 'If':True})


# Simple runner
suite = unittest.defaultTestLoader.loadTestsFromTestCase(TestCodeFeatures)
unittest.TextTestRunner().run(suite)
# Out:
# .......
# ----------------------------------------------------------------------
# Ran 7 tests in 0.018s
#
# OK
# <unittest.runner.TextTestResult run=7 errors=0 failures=0>

# %%
# And finally, we want to send back a dictionary of aggregate results rather than just the analysis of each solution.

def solution_features(solutions):

  """
  problemSkills -> ProblemKey -> featureType -> feature -> userKey -> True
  userSkills       -> UserKey -> featureType -> feature -> problemKey -> True

  """

  problemSkills = {}
  userSkills = {}

  for problemKey in solutions.keys():
    for userKey in solutions[problemKey]:
      src = solutions[problemKey][userKey]
      analysis = code_features(src)
      #print(src)
      #print(analysis)
      for featureType in analysis:
        #print(problemKey, userKey, featureType, analysis[featureType])
        for feature in analysis[featureType]:
          #Add the analysis to the problemSkills dictionary.
          if not problemKey in problemSkills:
            problemSkills[problemKey] = {}
          if not featureType in problemSkills[problemKey]:
            problemSkills[problemKey][featureType] = {}
          if not feature in problemSkills[problemKey][featureType]:
            problemSkills[problemKey][featureType][feature] = {}

          # Add userKey true to feature dictionary.
          problemSkills[problemKey][featureType][feature][userKey] = True

          # Add the same data to userSkills
          if not userKey in userSkills:
            userSkills[userKey] = {}
          if not featureType in userSkills[userKey]:
            userSkills[userKey][featureType] = {}
          if not feature in userSkills[userKey][featureType]:
            userSkills[userKey][featureType][feature] = {}

          # Add problemKey true to feature dictionary.
          userSkills[userKey][featureType][feature][problemKey] = True

  return {"problemSkills":problemSkills, "userSkills": userSkills}


final_results = solution_features(student_solutions)

for problemKey in final_results["problemSkills"]:
  print("----- All features used by all users to solve problem", problemKey, "-----")
  for featureType,features in final_results["problemSkills"][problemKey].items():
    for feature, userKeys in features.items():
      print(featureType, feature, len(userKeys))


for userKey in final_results["userSkills"]:
  print("----- All features used by user ",userKey,"to solve all problems. -----")
  for featureType,features in final_results["userSkills"][userKey].items():
    for feature, problemKeys in features.items():
      print(featureType, feature, len(problemKeys))
# Out:
# ----- All features used by all users to solve problem -LDkAuy-IFXOJoBILgL6 -----
# statements Return 24
# expressions * 24
# ----- All features used by all users to solve problem -LDkAxmbeJ9r3DcfU0ZW -----
# statements If 18
# statements Return 18
# expressions > 16
# expressions == 10
# expressions < 9
# expressions * 1
# ----- All features used by all users to solve problem -LDkB1-McVTufbnKUw-8 -----
# statements For 11
# statements Return 16
# statements If 11
# expressions == 15
# expressions + 11
# expressions > 1
# expressions < 1
# functions len 5
# functions sum 2
# functions list 1
# functions filter 1
# ----- All features used by all users to solve problem -LDkB3z2Pp9wRf-zCxBk -----
# statements Return 15
# statements For 9
# statements If 1
# functions sum 6
# functions len 1
# functions int 1
# expressions + 9
# expressions == 1
# ----- All features used by all users to solve problem -LDkB7FprNZsNyK67zFC -----
# statements For 12
# statements Return 16
# statements If 12
# functions type 8
# functions len 1
# functions isinstance 8
# functions sum 4
# functions map 1
# functions list 1
# functions filter 1
# expressions + 12
# expressions == 5
# ----- All features used by all users to solve problem -LDkBAqpHP6trY1K4Bj5 -----
# statements For 11
# statements Return 15
# statements If 10
# expressions == 12
# expressions + 11
# functions type 6
# functions len 1
# functions isinstance 8
# functions sum 4
# functions int 1
# functions list 1
# functions filter 1
# ----- All features used by all users to solve problem -LDkBE8kMmBdo9gKt02Z -----
# statements Return 13
# statements If 2
# statements While 1
# statements For 1
# functions .replace 11
# functions .find 1
# functions len 2
# functions range 1
# expressions + 2
# expressions - 1
# expressions == 1
# ----- All features used by all users to solve problem -LDkBHslDND-YNg-u9i1 -----
# statements Return 13
# statements For 6
# statements While 1
# functions dict 7
# functions zip 2
# functions .values 4
# functions .keys 4
# functions tuple 1
# functions .items 7
# functions eval 1
# functions len 2
# functions str 1
# functions list 1
# functions range 1
# expressions + 2
# expressions < 1
# ----- All features used by all users to solve problem -LDkBNZ-WjGg-vAEHofN -----
# statements Return 11
# statements For 8
# statements If 6
# functions Counter 3
# functions dict 4
# functions list 1
# functions .count 1
# functions .keys 1
# functions defaultdict 1
# imports Counter 3
# imports histogram 1
# imports defaultdict 1
# expressions + 7
# expressions == 2
# ----- All features used by user  0NloChcpl6bV3cpfKk0zJx59IEZ2 to solve all problems. -----
# statements Return 9
# statements If 4
# statements For 3
# expressions * 1
# expressions > 1
# expressions == 3
# expressions + 3
# functions sum 1
# functions type 1
# functions .replace 1
# functions dict 1
# functions zip 1
# functions .values 1
# functions .keys 1
# functions Counter 1
# imports Counter 1
# ----- All features used by user  4dCdPX3MVlWNagub1pTpWBjNz2A2 to solve all problems. -----
# statements Return 6
# statements If 4
# statements For 4
# expressions * 1
# expressions > 1
# expressions == 4
# expressions + 4
# functions type 2
# ----- All features used by user  6Tkig5Bmg3SFm3WPjyY6JclHYO53 to solve all problems. -----
# statements Return 9
# statements If 6
# statements For 6
# expressions * 1
# expressions > 1
# expressions < 1
# expressions == 5
# expressions + 6
# functions len 3
# functions type 2
# functions .replace 1
# functions dict 2
# ----- All features used by user  85t8IgfUtld71Eobas8RvHCRZZk1 to solve all problems. -----
# statements Return 1
# expressions * 1
# ----- All features used by user  95yMg7xQSIgYUdGDQXEcnn1gvJ83 to solve all problems. -----
# statements Return 1
# expressions * 1
# ----- All features used by user  Daa0PXSqy4OEc3jY45VuZwzn9JL2 to solve all problems. -----
# statements Return 9
# statements If 2
# statements For 6
# expressions * 1
# expressions > 1
# expressions == 3
# expressions + 4
# functions isinstance 2
# functions .replace 1
# functions tuple 1
# functions .items 1
# functions list 1
# functions .count 1
# ----- All features used by user  InEAFwVEZNTqfg0RtCTdl79ME1p2 to solve all problems. -----
# statements Return 1
# expressions * 1
# ----- All features used by user  IrnPht6xFqcG0P436Gg0Ka8QX552 to solve all problems. -----
# statements Return 1
# expressions * 1
# ----- All features used by user  JaXyc6jxkhSNmd9LmYbi3SWVVT72 to solve all problems. -----
# statements Return 1
# expressions * 1
# ----- All features used by user  LlYmkwKZscTljV5ogObhEGBIjpi2 to solve all problems. -----
# statements Return 9
# statements If 5
# statements For 6
# expressions * 1
# expressions > 1
# expressions == 3
# expressions + 5
# functions isinstance 2
# functions .replace 1
# functions dict 2
# ----- All features used by user  Oodwq4Vhh2T9zmgGkxd6kXsBZhw1 to solve all problems. -----
# statements Return 6
# statements If 4
# statements For 4
# expressions * 1
# expressions == 3
# expressions > 2
# expressions + 4
# functions len 1
# functions isinstance 2
# ----- All features used by user  S3iSosxCuTPHGAHGPHSe4xrnjPG3 to solve all problems. -----
# statements Return 1
# expressions * 1
# ----- All features used by user  UhspAheoKvbMJ6rDLnBjKnMM4kj1 to solve all problems. -----
# statements Return 7
# statements If 1
# expressions * 1
# expressions < 1
# functions len 1
# functions sum 2
# functions isinstance 2
# functions .replace 1
# functions .items 1
# imports histogram 1
# ----- All features used by user  VVdCBPkgn2RascyF7E7KnNU3R5q1 to solve all problems. -----
# statements Return 5
# statements If 2
# statements For 1
# expressions * 1
# expressions > 1
# expressions == 2
# expressions + 1
# functions len 1
# functions sum 1
# functions type 1
# ----- All features used by user  WdDD6uW6icUhsnzntgPDSVUoCp42 to solve all problems. -----
# statements Return 2
# statements If 1
# expressions * 1
# expressions > 1
# expressions == 1
# ----- All features used by user  Z84QafY8xCWefoOVfbEZah4UZiW2 to solve all problems. -----
# statements Return 8
# statements If 4
# statements For 4
# statements While 1
# expressions * 1
# expressions < 2
# expressions == 4
# expressions + 5
# functions int 1
# functions type 2
# functions .replace 1
# functions eval 1
# functions dict 1
# functions len 1
# functions str 1
# functions .values 1
# functions .keys 1
# ----- All features used by user  cybE1DRNYtZCtCQrEYjZFI6oVa62 to solve all problems. -----
# statements Return 9
# statements If 2
# expressions * 1
# expressions > 1
# expressions < 1
# expressions == 2
# functions sum 4
# functions map 1
# functions type 2
# functions .replace 1
# functions .items 1
# functions Counter 1
# imports Counter 1
# ----- All features used by user  gqFNZRjR63UATiVX3omS0wQ2TzW2 to solve all problems. -----
# statements Return 2
# statements If 1
# expressions * 1
# expressions > 1
# expressions == 1
# ----- All features used by user  hUK6CPhD4UWnKKSCBq3DU8OJo6O2 to solve all problems. -----
# statements Return 9
# statements If 6
# statements For 6
# expressions * 2
# expressions > 1
# expressions < 1
# expressions == 1
# expressions + 5
# functions isinstance 2
# functions .replace 1
# functions .items 1
# functions .keys 1
# ----- All features used by user  oTeidj1LEtcR9KrvTadnTGHDw9z2 to solve all problems. -----
# statements Return 9
# statements If 4
# statements For 3
# statements While 1
# expressions * 1
# expressions > 1
# expressions == 4
# expressions + 4
# functions sum 1
# functions type 2
# functions int 1
# functions .find 1
# functions len 1
# functions dict 2
# functions .items 1
# functions Counter 1
# imports Counter 1
# ----- All features used by user  ptF1d0QwSDOt2ApSkJa2tw3Aktn1 to solve all problems. -----
# statements Return 9
# statements If 6
# statements For 7
# expressions * 1
# expressions < 2
# expressions > 1
# expressions == 5
# expressions + 6
# expressions - 1
# functions len 3
# functions type 2
# functions range 2
# functions list 1
# functions .values 1
# functions .keys 1
# ----- All features used by user  r168FElrvNhZlxwA9Fl3tPIhRze2 to solve all problems. -----
# statements Return 9
# statements If 1
# statements For 1
# expressions * 1
# expressions > 1
# expressions < 1
# expressions == 1
# expressions + 1
# functions len 1
# functions list 3
# functions filter 3
# functions sum 3
# functions isinstance 2
# functions .replace 1
# functions dict 1
# functions zip 1
# functions .values 1
# functions .keys 1
# functions defaultdict 1
# imports defaultdict 1
# ----- All features used by user  xHnJN4g1QKhrYsxNX3xjjl7AyF92 to solve all problems. -----
# statements Return 9
# statements If 5
# statements For 6
# expressions * 1
# expressions > 1
# expressions < 1
# expressions == 2
# expressions + 5
# functions isinstance 2
# functions .replace 1
# functions .items 1
# ----- All features used by user  zbEJ9pSOHtUJwSO52qxt43bY62L2 to solve all problems. -----
# statements Return 9
# statements If 2
# statements For 1
# expressions * 1
# expressions > 1
# expressions < 1
# expressions == 2
# expressions + 1
# functions sum 4
# functions isinstance 2
# functions .replace 1
# functions dict 2
# functions .items 1

# %%
# Create an AWS Lambda function to return the results of solution_features()
# when posted a dictionary of user solution.




# Create a chart of the features by percentage used across all available examples.
# Find the difference between two aggregated lists.
